# %%
import plot_wien2k as pw
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r1 = '/home/loner/Documents/Science/Projects/DFT/'
r2 = '/home/loner/Documents/'
r3 = '/home/loner/Documents/Science/Projects/DFT/BBO_FM/'

# %%
xas = pw.Xas(r1 + 'BKBO_exc/O_1s.xspec')
xas1 = pw.Xas(r1 + 'BKBO_gr/O_1s.xspec')

# %%
xas.data.head(2)
# Out:
#    Energy  Intensity
# 0   -2.00   0.000005
# 1   -1.98   0.000006

# %%
xas.get_columns()
# Out:
# Index([u'Energy', u'Intensity'], dtype='object')

# %%
#Adding xas1 in xas
xas << xas1

# %%
xas.data.head(2)
# Out:
#    Energy  Intensity  Energy_O_1s  Intensity_O_1s
# 0   -2.00   0.000005        -2.00        0.000005
# 1   -1.98   0.000006        -1.98        0.000006

# %%
xas.get_columns()
# Out:
# Index([u'Energy', u'Intensity', u'Energy_O_1s', u'Intensity_O_1s'], dtype='object')

# %%
xas.data['del'] = 100 * (1.0 - (xas.data.Intensity / xas.data.Intensity_O_1s) )#/ xas.data.Intensity 
xas.data['diff'] = 10*(xas.data.Intensity - xas.data.Intensity_O_1s)
cols = xas.get_columns()[1::2]

# %%
xas.plot(col=cols[:2], names=[r'Excited', 'Ground'], xlab='Energy [eV]', 
         figsize=(20, 10), colors=['purple', 'orange'],  ylab='Intensity',  fontsize=50, alpha=0,
         ytickslabels=[], zeroline=1, legend_font=40, location='upper left', 
        )#save='./Pictures/men_pid/BBO_Bi_Medge')
# Out:
# /home/loner/anaconda3/envs/p2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
xas.plot(col=['del'], names=[r'$1 - \frac{I_{exc}}{I_{gr}}$'], xlab='Energy [eV]', 
         figsize=(20, 5), colors=['red'],  ylab='%',  fontsize=40, alpha=0,
         zeroline=1, legend_font=40, ytickslabels=np.arange(-5, 16, 5), location='upper left', handlelength=0.2)

# %%
xas.plot(col=['diff'], names=[r'$I_{exc} - I_{gr}$'], xlab='Energy [eV]', 
         figsize=(20, 5), colors=['red'],  ylab='Intensity',  fontsize=40, alpha=0,
         ytickslabels=[], zeroline=1,  legend_font = 35, location='upper right')
